# %% [markdown]
# Загрузка данных

# %%
import pandas as pd

# %% [markdown]
# #1 Read SCV file

# %%
df = pd.read_csv("../data/feed-views.log",skipfooter=2,engine='python',skiprows=[2,3],sep='\t',names=['datetime','user'],index_col='datetime')

# %%
df.head()
# Out:
#                               user
# datetime
# 2020-04-17 12:01:08.463179   artem
# 2020-04-17 12:01:23.743946   artem
# 2020-04-17 12:35:52.735016   artem
# 2020-04-17 12:36:21.401412  oksana
# 2020-04-17 12:36:22.023355  oksana

# %%
df.count()
# Out:
# user    1072
# dtype: int64

# %%
df.tail()
# Out:
#                                  user
# datetime
# 2020-05-21 16:36:40.915488  ekaterina
# 2020-05-21 17:49:36.429237      maxim
# 2020-05-21 18:45:20.441142  valentina
# 2020-05-21 23:03:06.457819      maxim
# 2020-05-21 23:23:49.995349      pavel

# %% [markdown]
# #2 Rename datetime to date_time

# %%
df.index.names = ["date_time"]
df.head()
# Out:
#                               user
# date_time
# 2020-04-17 12:01:08.463179   artem
# 2020-04-17 12:01:23.743946   artem
# 2020-04-17 12:35:52.735016   artem
# 2020-04-17 12:36:21.401412  oksana
# 2020-04-17 12:36:22.023355  oksana

# %%
df.tail()
# Out:
#                                  user
# date_time
# 2020-05-21 16:36:40.915488  ekaterina
# 2020-05-21 17:49:36.429237      maxim
# 2020-05-21 18:45:20.441142  valentina
# 2020-05-21 23:03:06.457819      maxim
# 2020-05-21 23:23:49.995349      pavel

# %% [markdown]
# #3 to_csv

# %%
df.head().to_csv("../ex00/feed-views-semicolon.log",sep=';')
df.head()
# Out:
#                               user
# date_time
# 2020-04-17 12:01:08.463179   artem
# 2020-04-17 12:01:23.743946   artem
# 2020-04-17 12:35:52.735016   artem
# 2020-04-17 12:36:21.401412  oksana
# 2020-04-17 12:36:22.023355  oksana

# %% [markdown]
# OR

# %%
df.tail().to_csv("../ex00/feed-views-semicolon.log",sep=';')

# %% [markdown]
# OR

# %%
df.to_csv("../ex00/feed-views-semicolon.log",sep=';')
